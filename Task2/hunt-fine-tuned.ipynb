# %%
import os, shutil, pathlib
import keras
import matplotlib.pyplot as plt
import numpy as np
from keras import layers
from keras.utils import image_dataset_from_directory

# %%
IMG_SIZE = (224, 224)

train_ds = keras.utils.image_dataset_from_directory(
    "hunt_dataset_split/train",
    image_size=IMG_SIZE,
    batch_size=8
)

val_ds = keras.utils.image_dataset_from_directory(
    "hunt_dataset_split/val",
    image_size=IMG_SIZE,
    batch_size=8
)

test_ds = keras.utils.image_dataset_from_directory(
    "hunt_dataset_split/test",
    image_size=IMG_SIZE,
    batch_size=8
)
# Out:
# Found 118 files belonging to 2 classes.
# Found 24 files belonging to 2 classes.
# Found 27 files belonging to 2 classes.

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2)
    ]
)

# %%
conv_base = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False
)

conv_base.trainable = False
conv_base.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_16 (InputLayer)     │ (None, None, None, 3)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, None, None, 64) │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, None, None, 64) │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, None, None, 64) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, None, None,     │        73,856 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, None, None,     │       147,584 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, None, None,     │       295,168 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, None, None,     │     1,180,160 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 512)                   │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
inputs = keras.Input(shape=(224, 224, 3))
x = data_augmentation(inputs)
x = keras.applications.vgg16.preprocess_input(x)
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(128)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)

model = keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional_29"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_17      │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_4        │ (None, 224, 224,  │          0 │ input_layer_17[0… │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_18         │ (None, 224, 224)  │          0 │ sequential_4[0][… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_19         │ (None, 224, 224)  │          0 │ sequential_4[0][… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_20         │ (None, 224, 224)  │          0 │ sequential_4[0][… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack_12 (Stack)    │ (None, 224, 224,  │          0 │ get_item_18[0][0… │
# │                     │ 3)                │            │ get_item_19[0][0… │
# │                     │                   │            │ get_item_20[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 224, 224,  │          0 │ stack_12[0][0]    │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vgg16 (Functional)  │ (None, 7, 7, 512) │ 14,714,688 │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_6 (Flatten) │ (None, 25088)     │          0 │ vgg16[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 128)       │  3,211,392 │ flatten_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 128)       │          0 │ dense_12[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 1)         │        129 │ dropout_6[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 17,926,209 (68.38 MB)
#  Trainable params: 3,211,521 (12.25 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"]
)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction.keras",
        save_best_only=True,
        monitor="val_loss"
    )
]

# %%
history = model.fit(
    train_ds,
    epochs=50,
    validation_data=val_ds,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.5413 - loss: 12.2834 - val_accuracy: 0.7500 - val_loss: 12.9997
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.7624 - loss: 13.5209 - val_accuracy: 0.8333 - val_loss: 18.4321
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.8447 - loss: 8.0108 - val_accuracy: 0.7917 - val_loss: 17.5830
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.8993 - loss: 6.1932 - val_accuracy: 0.8750 - val_loss: 12.6950
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8852 - loss: 4.9966 - val_accuracy: 0.8750 - val_loss: 17.9740
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9525 - loss: 1.7619 - val_accuracy: 0.7500 - val_loss: 24.3935
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9080 - loss: 6.6645 - val_accuracy: 0.7917 - val_loss: 23.6518
# Epoch 8/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9487 - loss: 2.2770 - val_accuracy: 0.7917 - val_loss: 26.6847
# Epoch 9/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9299 - loss: 5.1002 - val_accuracy: 0.7500 - val_loss: 31.4574
# Epoch 10/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.9196 - loss: 5.0043 - val_accuracy: 0.8333 - val_loss: 42.4957
# Epoch 11/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9812 - loss: 1.0899 - val_accuracy: 0.8750 - val_loss: 34.5487
# Epoch 12/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9373 - loss: 2.1630 - val_accuracy: 0.8750 - val_loss: 26.0074
# Epoch 13/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9551 - loss: 1.8462 - val_accuracy: 0.9167 - val_loss: 25.0948
# Epoch 14/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9836 - loss: 0.4774 - val_accuracy: 0.8750 - val_loss: 15.4991
# Epoch 15/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9319 - loss: 3.5114 - val_accuracy: 0.8750 - val_loss: 16.0653
# Epoch 16/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9336 - loss: 4.9299 - val_accuracy: 0.7917 - val_loss: 35.1491
# Epoch 17/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9084 - loss: 3.9339 - val_accuracy: 0.8333 - val_loss: 8.7050
# Epoch 18/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.9572 - loss: 4.1285 - val_accuracy: 0.9167 - val_loss: 18.0719
# Epoch 19/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9850 - loss: 0.3154 - val_accuracy: 0.9167 - val_loss: 20.4205
# Epoch 20/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.9725 - loss: 0.1256 - val_accuracy: 0.9167 - val_loss: 15.4035
# Epoch 21/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9712 - loss: 0.8229 - val_accuracy: 0.8333 - val_loss: 13.9027
# Epoch 22/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 4.3755e-11 - val_accuracy: 0.8333 - val_loss: 15.1094
# Epoch 23/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9506 - loss: 0.4523 - val_accuracy: 0.8333 - val_loss: 14.6233
# Epoch 24/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9870 - loss: 0.5364 - val_accuracy: 0.8333 - val_loss: 13.6420
# Epoch 25/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9964 - loss: 0.0565 - val_accuracy: 0.8333 - val_loss: 12.2337
# Epoch 26/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9850 - loss: 1.1724 - val_accuracy: 0.9167 - val_loss: 12.7590
# Epoch 27/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9562 - loss: 3.8482 - val_accuracy: 0.8750 - val_loss: 20.9340
# Epoch 28/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9606 - loss: 1.1213 - val_accuracy: 0.8750 - val_loss: 8.9557
# Epoch 29/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9936 - loss: 0.6272 - val_accuracy: 0.8750 - val_loss: 12.6562
# Epoch 30/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9410 - loss: 3.2185 - val_accuracy: 0.8750 - val_loss: 27.4494
# Epoch 31/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9984 - loss: 0.0147 - val_accuracy: 0.8750 - val_loss: 25.0939
# Epoch 32/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9681 - loss: 2.3606 - val_accuracy: 0.9167 - val_loss: 13.2114
# Epoch 33/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9575 - loss: 1.4294 - val_accuracy: 0.9167 - val_loss: 10.5826
# Epoch 34/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9785 - loss: 0.1391 - val_accuracy: 0.8750 - val_loss: 23.0185
# Epoch 35/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9850 - loss: 0.2712 - val_accuracy: 0.9167 - val_loss: 17.4506
# Epoch 36/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9956 - loss: 0.0548 - val_accuracy: 0.9167 - val_loss: 13.7434
# Epoch 37/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9876 - loss: 0.6126 - val_accuracy: 0.8750 - val_loss: 17.5843
# Epoch 38/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9814 - loss: 0.3321 - val_accuracy: 0.9167 - val_loss: 13.5157
# Epoch 39/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9948 - loss: 0.1641 - val_accuracy: 0.9167 - val_loss: 12.5028
# Epoch 40/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 6.8161e-13 - val_accuracy: 0.9167 - val_loss: 11.8534
# Epoch 41/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9800 - loss: 0.9736 - val_accuracy: 0.9167 - val_loss: 12.2782
# Epoch 42/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 1.0000 - loss: 2.8179e-08 - val_accuracy: 0.9167 - val_loss: 16.3816
# Epoch 43/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9722 - loss: 0.0820 - val_accuracy: 0.9167 - val_loss: 14.1440
# Epoch 44/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9715 - loss: 0.4239 - val_accuracy: 0.8750 - val_loss: 17.4143
# Epoch 45/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9836 - loss: 0.8268 - val_accuracy: 0.9167 - val_loss: 16.3588
# Epoch 46/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9650 - loss: 4.2462 - val_accuracy: 0.8333 - val_loss: 26.8693
# Epoch 47/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9882 - loss: 1.7623 - val_accuracy: 0.9167 - val_loss: 20.0687
# Epoch 48/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 1.0000 - loss: 3.6155e-15 - val_accuracy: 0.8750 - val_loss: 23.5457
# Epoch 49/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.9843 - loss: 0.8638 - val_accuracy: 0.9167 - val_loss: 19.6978
# Epoch 50/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9546 - loss: 3.8853 - val_accuracy: 0.8750 - val_loss: 22.6095

# %%
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = list(range(1, len(accuracy)+1))

plt.plot(epochs, accuracy, label="Training accuracy")
plt.plot(epochs, val_accuracy, label="Validation accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.figure()
plt.plot(epochs, loss, label="Training loss")
plt.plot(epochs, val_loss, label="Validation loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
test_model = keras.models.load_model("fine_tuning.keras")
test_loss, test_acc = test_model.evaluate(test_ds)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 869ms/step - accuracy: 0.8574 - loss: 16.4829
# Test accuracy: 0.852

# %% [markdown]
# Fine tuning the model

# %%
conv_base.trainable = True

for layer in conv_base.layers[:-4]:
    layer.trainable = False

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer=keras.optimizers.RMSprop(learning_rate=1e-5),
    metrics=["accuracy"]
)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning.keras",
        save_best_only=True,
        monitor="val_loss"
    )
]

# %%
history = model.fit(
    train_ds,
    epochs=30,
    validation_data=val_ds,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 25s 2s/step - accuracy: 0.9822 - loss: 0.7627 - val_accuracy: 0.8750 - val_loss: 19.5594
# Epoch 2/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9683 - loss: 5.3637 - val_accuracy: 0.8750 - val_loss: 20.5472
# Epoch 3/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9894 - loss: 0.0319 - val_accuracy: 0.8750 - val_loss: 20.6131
# Epoch 4/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 1.0000 - loss: 6.3104e-22 - val_accuracy: 0.8750 - val_loss: 20.6131
# Epoch 5/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.9853 - loss: 0.6149 - val_accuracy: 0.8750 - val_loss: 27.2612
# Epoch 6/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.9964 - loss: 0.0494 - val_accuracy: 0.8750 - val_loss: 21.3853
# Epoch 7/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 1.0000 - loss: 4.8344e-35 - val_accuracy: 0.8750 - val_loss: 21.3853
# Epoch 8/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 1.0000 - loss: 2.7235e-08 - val_accuracy: 0.8750 - val_loss: 21.3844
# Epoch 9/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 1.0000 - loss: 6.5344e-04 - val_accuracy: 0.9167 - val_loss: 19.3476
# Epoch 10/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.9700 - loss: 2.3470 - val_accuracy: 0.8750 - val_loss: 21.9203
# Epoch 11/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.9948 - loss: 0.0682 - val_accuracy: 0.8750 - val_loss: 26.1667
# Epoch 12/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.9323 - loss: 2.2266 - val_accuracy: 0.8750 - val_loss: 21.5497
# Epoch 13/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.9673 - loss: 0.9971 - val_accuracy: 0.8750 - val_loss: 21.1734
# Epoch 14/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.9814 - loss: 0.1861 - val_accuracy: 0.9167 - val_loss: 17.6960
# Epoch 15/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 1.0000 - loss: 8.7438e-18 - val_accuracy: 0.9167 - val_loss: 17.6960
# Epoch 16/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9898 - loss: 0.4480 - val_accuracy: 0.8750 - val_loss: 23.3206
# Epoch 17/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - accuracy: 1.0000 - loss: 1.3088e-33 - val_accuracy: 0.8750 - val_loss: 23.3206
# Epoch 18/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - accuracy: 1.0000 - loss: 7.2139e-21 - val_accuracy: 0.8750 - val_loss: 23.3206
# Epoch 19/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 45s 3s/step - accuracy: 0.9948 - loss: 0.3859 - val_accuracy: 0.9167 - val_loss: 16.9063
# Epoch 20/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 49s 3s/step - accuracy: 0.9853 - loss: 0.6466 - val_accuracy: 0.8750 - val_loss: 20.5003
# Epoch 21/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9914 - loss: 0.4839 - val_accuracy: 0.9167 - val_loss: 14.6027
# Epoch 22/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 1.0000 - loss: 4.5967e-17 - val_accuracy: 0.9167 - val_loss: 14.6027
# Epoch 23/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.9964 - loss: 0.0407 - val_accuracy: 0.8750 - val_loss: 20.7083
# Epoch 24/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.9938 - loss: 0.1349 - val_accuracy: 0.8750 - val_loss: 15.3313
# Epoch 25/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - accuracy: 0.9814 - loss: 2.3405 - val_accuracy: 0.8750 - val_loss: 22.2805
# Epoch 26/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.9914 - loss: 0.0205 - val_accuracy: 0.8333 - val_loss: 26.9544
# Epoch 27/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 44s 3s/step - accuracy: 0.9914 - loss: 0.0239 - val_accuracy: 0.8750 - val_loss: 21.7561
# Epoch 28/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 1.0000 - loss: 2.0488e-38 - val_accuracy: 0.8750 - val_loss: 21.7562
# Epoch 29/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 51s 3s/step - accuracy: 1.0000 - loss: 1.6456e-04 - val_accuracy: 0.8750 - val_loss: 16.1795
# Epoch 30/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 1.0000 - loss: 3.5757e-06 - val_accuracy: 0.8750 - val_loss: 16.6152

# %%
test_model = keras.models.load_model("fine_tuning.keras")

test_loss, test_acc = test_model.evaluate(test_ds)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.7843 - loss: 27.2858
# Test accuracy: 0.815
